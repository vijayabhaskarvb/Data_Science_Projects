# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel('Employees.xlsx')
dataset.head()
# Out:
#    No First Name Last Name  Gender Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male 2018-04-04      2     Quality Control
# 1   2       Omar    Hishan    Male 2020-05-21      0     Quality Control
# 2   3      Ailya    Sharaf  Female 2017-09-28      3  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male 2018-08-14      2       Manufacturing
# 4   5      Ahmad     Bikri    Male 2020-03-11      0       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# 0            1              0             183
# ...

# %%
dataset.shape
# Out:
# (689, 15)

# %%
dataset.info()

dataset.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Years           689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    int64
#  11  Job Rate        689 non-null    float64
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(6)
# memory usage: 80.9+ KB
# ...

# %%
dataset.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
dataset.isna().sum()
# Out:
# No                0
# First Name        0
# Last Name         0
# Gender            0
# Start Date        0
# Years             0
# Department        0
# Country           0
# Center            0
# Monthly Salary    0
# Annual Salary     0
# Job Rate          0
# Sick Leaves       0
# Unpaid Leaves     0
# Overtime Hours    0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset['First Name'] = dataset['First Name'] + dataset['Last Name']
dataset.head()
# Out:
#    No   First Name Last Name  Gender Start Date  Years          Department  \
# 0   1  GhadirHmshw     Hmshw    Male 2018-04-04      2     Quality Control
# 1   2   OmarHishan    Hishan    Male 2020-05-21      0     Quality Control
# 2   3  AilyaSharaf    Sharaf  Female 2017-09-28      3  Major Mfg Projects
# 3   4    LwiyQbany     Qbany    Male 2018-08-14      2       Manufacturing
# 4   5   AhmadBikri     Bikri    Male 2020-03-11      0       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# ...

# %%
dataset = dataset.drop(['Last Name'], axis = 1)
dataset.columns
# Out:
# Index(['No', 'First Name', 'Gender', 'Start Date', 'Years', 'Department',
#        'Country', 'Center', 'Monthly Salary', 'Annual Salary', 'Job Rate',
#        'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
dataset.rename(columns={'First Name' : 'Name'}, inplace = True)
dataset.head(2)
# Out:
#    No         Name Gender Start Date  Years       Department       Country  \
# 0   1  GhadirHmshw   Male 2018-04-04      2  Quality Control         Egypt
# 1   2   OmarHishan   Male 2020-05-21      0  Quality Control  Saudi Arabia
#
#   Center  Monthly Salary  Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  \
# 0   West            1560          18720       3.0            1              0
# 1   West            3247          38964       1.0            0              5
#
#    Overtime Hours
# 0             183
# 1             198

# %%
sns.set(style='whitegrid')

# %%
dataset['Gender'].value_counts().plot(kind = 'pie', color = ['Blue', 'Orange'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('')
plt.show()

# %%
dataset['Country'].value_counts().plot(kind = 'bar', color = ['Blue', 'Orange'])
plt.title('Country Distribution')
plt.xlabel('Country')
plt.ylabel('')
plt.xticks(rotation = 20)
plt.tight_layout()
plt.show()

# %%
dataset['Center'].value_counts().plot(kind = 'pie', color = ['Blue', 'Orange'])
plt.title('Center Distribution')
plt.xlabel('Center')
plt.ylabel('')
plt.xticks(rotation = 20)
plt.tight_layout()
plt.show()

# %%
dept = dataset['Department'].unique()
dept
# Out:
# array(['Quality Control', 'Major Mfg Projects', 'Manufacturing',
#        'Product Development', 'Sales', 'Account Management',
#        'Green Building', 'IT', 'Facilities/Engineering', 'Marketing',
#        'Manufacturing Admin', 'Training', 'Quality Assurance',
#        'Professional Training Group', 'Environmental Compliance',
#        'Creative', 'Research/Development', 'Environmental Health/Safety',
#        'Human Resources', 'Research Center'], dtype=object)

# %%
dataset['Department'].value_counts().plot(kind = 'bar', color = ['Blue', 'Orange'], figsize=(10, 8))
plt.title('Department Distribution')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %%
# Department wise who gets higher salary

dataset.groupby('Department')['Monthly Salary'].mean().sort_values(ascending=False).plot(kind='bar', figsize=(10, 6))
plt.title('Department wise Average Salary')
plt.xlabel('Department')
plt.ylabel('Annual Salary')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %%
dataset.groupby('Name')['Annual Salary'].sum().sort_values(ascending=False).head(10)
# Out:
# Name
# MuhamadKhayr       83388
# MuhamadHamzat      72192
# MuhamadAlkhatib    69756
# MuhamadAlmisri     62880
# MuhamadHusayn      60960
# MuhamadAyman       55140
# MuhamadKhalid      54852
# AhmadHamuwd        53280
# MuhamadAmir        49884
# AhmadLaylana       48240
# Name: Annual Salary, dtype: int64

# %%
dataset.groupby('Name')['Annual Salary'].sum().sort_values(ascending=False).head(10).plot(kind = 'bar', figsize=(10,6), color=['blue', 'orange'])
plt.title('Top 10 Paid Employee')
plt.xlabel('Employee Name')
plt.ylabel('Annual Salary')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
dataset.groupby('Gender')['Monthly Salary'].mean().sort_values(ascending=False).plot(kind='pie', figsize=(10,6), color=['blue', 'orange'])
plt.title('Average Salary allocation by Gender')
plt.xlabel('Gender')
plt.ylabel('')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
dataset.groupby('Name')['Overtime Hours'].sum().sort_values(ascending=False).head(20).plot(kind='bar', figsize=(10,6), color=['blue', 'orange'])
plt.title('Overtime ')
plt.xlabel('Name')
plt.ylabel('Overtime Hours')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
dataset.head(2)
# Out:
#    No         Name Gender Start Date  Years       Department       Country  \
# 0   1  GhadirHmshw   Male 2018-04-04      2  Quality Control         Egypt
# 1   2   OmarHishan   Male 2020-05-21      0  Quality Control  Saudi Arabia
#
#   Center  Monthly Salary  Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  \
# 0   West            1560          18720       3.0            1              0
# 1   West            3247          38964       1.0            0              5
#
#    Overtime Hours
# 0             183
# 1             198

# %%
dataset = dataset.drop(['No','Name', 'Years', 'Start Date', 'Sick Leaves', 'Unpaid Leaves', 'Job Rate', 'Monthly Salary'], axis = 1)
dataset.head()
# Out:
#    Gender          Department               Country Center  Annual Salary  \
# 0    Male     Quality Control                 Egypt   West          18720
# 1    Male     Quality Control          Saudi Arabia   West          38964
# 2  Female  Major Mfg Projects          Saudi Arabia   West          30072
# 3    Male       Manufacturing  United Arab Emirates   Main          21936
# 4    Male       Manufacturing                 Egypt   Main          11640
#
#    Overtime Hours
# 0             183
# 1             198
# 2             192
# 3               7
# 4             121

# %%
x = dataset.drop(['Annual Salary'], axis = 1)
y = dataset['Annual Salary']
x
#y
# Out:
#      Gender              Department               Country Center  \
# 0      Male         Quality Control                 Egypt   West
# 1      Male         Quality Control          Saudi Arabia   West
# 2    Female      Major Mfg Projects          Saudi Arabia   West
# 3      Male           Manufacturing  United Arab Emirates   Main
# 4      Male           Manufacturing                 Egypt   Main
# ..      ...                     ...                   ...    ...
# 684    Male               Marketing               Lebanon  South
# 685    Male  Facilities/Engineering                 Egypt  North
# 686    Male  Facilities/Engineering                 Egypt  North
# 687    Male                Creative                 Egypt  North
# 688    Male                      IT  United Arab Emirates  North
#
#      Overtime Hours
# 0               183
# 1               198
# 2               192
# 3                 7
# 4               121
# ..              ...
# 684               1
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

categorical_cols = x.select_dtypes(include=['object']).columns
numeric_cols = x.select_dtypes(exclude=['object']).columns

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
    ('num', StandardScaler(), numeric_cols)
])
dataset.head()
# Out:
#    Gender          Department               Country Center  Annual Salary  \
# 0    Male     Quality Control                 Egypt   West          18720
# 1    Male     Quality Control          Saudi Arabia   West          38964
# 2  Female  Major Mfg Projects          Saudi Arabia   West          30072
# 3    Male       Manufacturing  United Arab Emirates   Main          21936
# 4    Male       Manufacturing                 Egypt   Main          11640
#
#    Overtime Hours
# 0             183
# 1             198
# 2             192
# 3               7
# 4             121

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=200, random_state=42))
])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R2 Score: {r2:.2f}")
# Out:
# Mean Absolute Error: 9206.14
# Mean Squared Error: 116857965.85
# R2 Score: -0.33

# %%
print(np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.to_numpy().reshape(len(y_test), 1)), axis=1))
# Out:
# [[22412.94       18432.        ]
#  [21292.71928571 10092.        ]
#  [24131.148      11796.        ]
#  [18121.11       17376.        ]
#  [24001.83       25236.        ]
#  [24159.18       12468.        ]
#  [29165.13       26304.        ]
#  [28764.013      20352.        ]
#  [23317.98       36228.        ]
#  [23736.569      35280.        ]
#  [28415.06       12540.        ]
#  [26858.15       14028.        ]
#  [25146.6        30576.        ]
#  [25833.207      17484.        ]
#  [20130.96       33336.        ]
#  [27383.269      13404.        ]
#  [26065.63085714 37896.        ]
#  [20801.205      21588.        ]
#  [34762.83       30300.        ]
#  [22758.864      18252.        ]
#  [25741.54285714  8676.        ]
#  [31511.94       37920.        ]
#  [21017.369      30552.        ]
#  [25507.79114286 33480.        ]
#  [26972.37       26244.        ]
#  [29476.98       24720.        ]
#  [13804.7        33444.        ]
#  [26875.54514286 28416.        ]
# ...

# %%
plt.scatter(y_test, y_pred)
plt.title('Actual vs Predicted Value')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Value')
plt.tight_layout()
plt.show()

# %%
x
# Out:
#      Gender              Department               Country Center  \
# 0      Male         Quality Control                 Egypt   West
# 1      Male         Quality Control          Saudi Arabia   West
# 2    Female      Major Mfg Projects          Saudi Arabia   West
# 3      Male           Manufacturing  United Arab Emirates   Main
# 4      Male           Manufacturing                 Egypt   Main
# ..      ...                     ...                   ...    ...
# 684    Male               Marketing               Lebanon  South
# 685    Male  Facilities/Engineering                 Egypt  North
# 686    Male  Facilities/Engineering                 Egypt  North
# 687    Male                Creative                 Egypt  North
# 688    Male                      IT  United Arab Emirates  North
#
#      Overtime Hours
# 0               183
# 1               198
# 2               192
# 3                 7
# 4               121
# ..              ...
# 684               1
# ...

# %%
y
# Out:
# 0      18720
# 1      38964
# 2      30072
# 3      21936
# 4      11640
#        ...
# 684    17424
# 685    38844
# 686    33828
# 687    24828
# 688    31272
# Name: Annual Salary, Length: 689, dtype: int64

# %%
user_input = pd.DataFrame([{
    'Gender': 'Female',
    'Department': 'Major Mfg Projects',
    'Country': 'Saudi Arabia',
    'Center': 'West',
    'Overtime Hours': 192
}])

results = model.predict(user_input)[0]
print(f"Predicted Annual Salary: {results}")
# Out:
# Predicted Annual Salary: 32304.0
