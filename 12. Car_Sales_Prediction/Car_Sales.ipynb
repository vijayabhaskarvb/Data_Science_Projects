# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('car_purchasing.csv', encoding = 'latin1')
dataset.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
dataset.info()

dataset.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# ...

# %%
dataset.shape
# Out:
# (500, 9)

# %%
dataset.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth',
#        'car purchase amount'],
#       dtype='object')

# %%
dataset.isna().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset['age'] = dataset['age'].astype(int)
dataset['age'].head(2)
# Out:
# 0    41
# 1    40
# Name: age, dtype: int32

# %%
sns.set(style='darkgrid')

# %%
dataset.head(2)
# Out:
#    customer name                                    customer e-mail   country  \
# 0  Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu  Bulgaria
# 1  Harlan Barnes                                eu.dolor@diam.co.uk    Belize
#
#    gender  age  annual Salary  credit card debt    net worth  \
# 0       0   41    62812.09301      11609.380910  238961.2505
# 1       0   40    66646.89292       9572.957136  530973.9078
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566

# %%
dataset['gender'].value_counts()
# Out:
# gender
# 1    253
# 0    247
# Name: count, dtype: int64

# %%
dataset['gender'].value_counts().plot(kind='pie', figsize=(10,6), color=['Orange', 'Blue'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
dataset['annual Salary'].plot(kind='line', figsize=(10,6))
plt.title('Annual Salary Distibution')
plt.xlabel('Annual Salary')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
dataset.groupby('gender')['annual Salary'].mean().plot(kind='bar', figsize=(10, 6), color=['orange', 'blue'])
plt.title("Average Salary by Gender")
plt.xlabel('Gender')
plt.ylabel('Average Salary')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
dataset.groupby('customer name')['annual Salary'].sum().head(10).sort_values(ascending=False).plot(kind='bar', figsize=(10,6), color = ['blue', 'orange'])
plt.title('Top 10 Customer based on Annual Salary')
plt.xlabel('Customer Name')
plt.ylabel('Annual Salary')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
dataset.groupby('customer name')['car purchase amount'].sum().head(10).sort_values(ascending=False).plot(kind='bar', figsize=(10,6), color = ['blue', 'orange'])
plt.title('Top 10 Customer based on Car Purchase')
plt.xlabel('Customer Name')
plt.ylabel('Car Purchase Amount')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
dataset.groupby('gender')['car purchase amount'].mean().plot(kind='pie', figsize=(10,6), color=['blue', 'orange'])
# Out:
# <Axes: ylabel='car purchase amount'>

# %%
dataset['car purchase amount'].plot(kind='box', figsize=(10, 6))
plt.title('Car Purchase')
plt.tight_layout()
plt.show()

# %%
dataset['country'].value_counts().head(20).sort_values(ascending=False).plot(kind='bar', figsize=(10,6), color = ['blue','orange'])
plt.title('Country Distribution')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
dataset.groupby('country')['car purchase amount'].mean().head(20).sort_values(ascending=False).plot(kind='bar', figsize=(10,6), color = ['blue', 'orange'])
plt.title('Country wise average car sales amount distribution')
plt.xlabel('Country')
plt.ylabel('Average Car purchase amount')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
dataset.head(2)
# Out:
#    customer name                                    customer e-mail   country  \
# 0  Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu  Bulgaria
# 1  Harlan Barnes                                eu.dolor@diam.co.uk    Belize
#
#    gender  age  annual Salary  credit card debt    net worth  \
# 0       0   41    62812.09301      11609.380910  238961.2505
# 1       0   40    66646.89292       9572.957136  530973.9078
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566

# %%
dataset = dataset.drop(['customer name', 'customer e-mail', 'credit card debt', 'country', 'gender'], axis = 1)
dataset.head()
# Out:
#    age  annual Salary    net worth  car purchase amount
# 0   41    62812.09301  238961.2505          35321.45877
# 1   40    66646.89292  530973.9078          45115.52566
# 2   43    53798.55112  638467.1773          42925.70921
# 3   58    79370.03798  548599.0524          67422.36313
# 4   57    59729.15130  560304.0671          55915.46248

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

x = dataset.drop('car purchase amount', axis=1)
y = dataset['car purchase amount']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

rfr_model = RandomForestRegressor(n_estimators=200, random_state=42)
rfr_model.fit(x_train, y_train)

y_pred = rfr_model.predict(x_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# MAE: 1395.688802984507
# RMSE: 4134407.215462038
# R2: 0.9617089354979557

# %%
from sklearn.tree import DecisionTreeRegressor

dtr_model = DecisionTreeRegressor()
dtr_model.fit(x_train, y_train)

y_pred = dtr_model.predict(x_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# MAE: 2435.4193219000003
# RMSE: 9997122.36164379
# R2: 0.9074110417200999

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(x_train, y_train)

y_pred = lr_model.predict(x_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# MAE: 208.51842860271137
# RMSE: 59512.91935988761
# R2: 0.999448817468828

# %%
corr = dataset.corr()
corr

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
plt.title('Correlation Matrix')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
y_pred = lr_model.predict(x_test)
print(np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.to_numpy().reshape(len(y_test), 1)), axis=1))
# Out:
# [[46390.24497296 46082.80993   ]
#  [44786.93989623 45058.8969    ]
#  [63362.25482226 63079.84329   ]
#  [32034.29308097 31837.22537   ]
#  [60459.23671897 60461.24268   ]
#  [63495.31593485 63140.05082   ]
#  [52589.31586791 52477.83479   ]
#  [54979.0517174  54755.42038   ]
#  [52792.46932946 52707.96816   ]
#  [47833.44009551 47869.82593   ]
#  [38304.41733129 38189.50601   ]
#  [56597.89852551 56229.4127    ]
#  [44177.0364069  44361.87507   ]
#  [38802.87966156 39002.0771    ]
#  [39776.97467302 39975.43302   ]
#  [54779.29884549 55174.98946   ]
#  [48918.76022962 48901.44342   ]
#  [17560.19455182 17584.56963   ]
#  [60497.56733389 60526.97788   ]
#  [49602.61624578 49991.60697   ]
#  [41113.20681433 41352.47071   ]
#  [53023.75092523 52785.16947   ]
#  [51339.51801988 51730.17434   ]
#  [37952.08250102 38042.80065   ]
#  [41435.72241231 41357.17897   ]
#  [38179.58689974 38243.06228   ]
#  [63751.35995904 64147.28888   ]
#  [47553.28959626 47984.42062   ]
# ...

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lr_model, x, y, cv=5)
print("Cross Val Accuracy:", scores.mean(), scores.std())
# Out:
# Cross Val Accuracy: 0.9994755438838145 6.724319962779244e-05

# %%
plt.scatter(y_test, y_pred)
plt.title('Actual Value vs Prediction Value')
plt.xlabel('Actual Value')
plt.ylabel('Predicted Value')
plt.tight_layout()
plt.show()

# %%
x.sample(5)
# Out:
#      age  annual Salary    net worth
# 268   54    55619.34152  229070.5491
# 42    37    50571.45969  348833.8403
# 203   57    50241.48985  607395.0183
# 329   44    45504.74866  374777.6929
# 0     41    62812.09301  238961.2505

# %%
user_input = [[45, 63722, 316128]]
results = lr_model.predict(user_input)[0]
print(f"Predicted Car Price: {results:.2f}")
# Out:
# Predicted Car Price: 41113.19
